# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from image_100 import *

# %%
img_orig = io.imread("./cat-323262_1920.jpg")

plt.imshow(img_orig)
plt.show()

# %% [markdown]
# ## rgb_to_gbr

# %% [markdown]
# \[R, G, B\]で格納されているイメージを\[B, G, R\]に変換する

# %%
img_gbr = utility.rgb_to_gbr(img_orig)
show_img.show_img_origin_and_conversion(img_orig, img_gbr)
