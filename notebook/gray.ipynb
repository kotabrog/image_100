# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from image_100 import *

# %%
img_orig = io.imread("./cat-323262_1920.jpg")

plt.imshow(img_orig)
plt.show()

# %% [markdown]
# ## rgb_to_gray

# %% [markdown]
# 画像をグレースケールにする

# %%
img_gray = gray.rgb_to_gray(img_orig)
show_img.show_img_origin_and_conversion(img_orig, img_gray, 'gray')

# %% [markdown]
# ## gray_to_2gray

# %% [markdown]
# グレースケール画像を二値化する

# %%
img_2gray = gray.gray_to_2gray(img_gray)
show_img.show_img_origin_and_conversion(img_gray, img_2gray, 'gray', 'gray')

# %%
img_2gray = gray.gray_to_2gray(img_gray, thresh=110)
show_img.show_img_origin_and_conversion(img_gray, img_2gray, 'gray', 'gray')

# %% [markdown]
# 画像を二値化する

# %%
img_2gray = gray.rgb_to_2gray(img_orig)
show_img.show_img_origin_and_conversion(img_orig, img_2gray, 'gray')

# %%
img_2gray = gray.rgb_to_2gray(img_orig, thresh=180)
show_img.show_img_origin_and_conversion(img_orig, img_2gray, 'gray')

# %% [markdown]
# ## otsu_thresh

# %% [markdown]
# 大津の二値化をする。閾値を自動的に決定し、グレースケールを二値化する

# %%
thresh, img_2gray = gray.otsu_thresh(img_gray)
print("thresh:", thresh)
show_img.show_img_origin_and_conversion(img_gray, img_2gray, 'gray', 'gray')
# Out:
# thresh: 160

# %% [markdown]
# ## rgb_to_otsu_thresh

# %% [markdown]
# RGBの画像をグレースケールに変換してから大津の二値化をする

# %%
thresh, img_2gray = gray.rgb_to_otsu_thresh(img_orig)
print("thresh:", thresh)
show_img.show_img_origin_and_conversion(img_orig, img_2gray, 'gray')
# Out:
# thresh: 160
