# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from image_100 import *

img_orig = io.imread("./cat-323262_1920.jpg")

plt.imshow(img_orig)
plt.show()

# %% [markdown]
# ## color_subtraction

# %%
img_subtraction = filtering.color_subtraction(img_orig)
show_img.show_img_origin_and_conversion(img_orig, img_subtraction)

# %%
img_subtraction = filtering.color_subtraction(img_orig, 16)
show_img.show_img_origin_and_conversion(img_orig, img_subtraction)

# %%
img_subtraction = filtering.color_subtraction(img_orig, num_division=2)
show_img.show_img_origin_and_conversion(img_orig, img_subtraction)

# %% [markdown]
# ## avarage_pooling

# %%
img_avarage_pooling = filtering.avarage_pooling(img_orig)
show_img.show_img_origin_and_conversion(img_orig, img_avarage_pooling)

# %%
img_avarage_pooling = filtering.avarage_pooling(img_orig, block_size=(16, 16))
show_img.show_img_origin_and_conversion(img_orig, img_avarage_pooling)

# %%
img_avarage_pooling = filtering.avarage_pooling(img_orig, block_size=(32, 32))
show_img.show_img_origin_and_conversion(img_orig, img_avarage_pooling)

# %% [markdown]
# ## max_pooling

# %%
img_max_pooling = filtering.max_pooling(img_orig)
show_img.show_img_origin_and_conversion(img_orig, img_max_pooling)

# %%
img_max_pooling = filtering.max_pooling(img_orig, block_size=(32, 32))
show_img.show_img_origin_and_conversion(img_orig, img_max_pooling)
